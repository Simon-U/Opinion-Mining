# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
from bs4 import BeautifulSoup
import spacy
import unidecode
from word2number import w2n
import contractions
from collections import Counter
from text_preprocessing_function import *
import time
import json
#import concurrent.futures
import nltk

# %%
#Showing graphs inline
# %matplotlib inline

# %%
nlp = spacy.load("en_core_web_lg")
#from spacy.lang.en import English
#nlp = English()

# %%
# exclude words from spacy stopwords list
deselect_stop_words = ['no', 'not']
for w in deselect_stop_words:
    nlp.vocab[w].is_stop = False

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'forty', 'only', 'nevertheless', 'whither', 'i', 'be', 'am', 'you', 'becomes', 'whether', 'anything', 'former', 'fifteen', 'then', 'sixty', 'beside', '’re', 'indeed', "'d", 'well', 'twelve', 'afterwards', 'which', 'such', 'onto', 'anywhere', 'into', 'within', '‘d', 'were', 'where', 'should', 'doing', 'n‘t', 'their', 'really', 'yours', 'no', 'except', 'first', "'s", 'those', 'alone', 'several', 'almost', 'via', 'been', 'by', 'my', 'due', "'re", 'on', 'somehow', 'same', 'this', 'whatever', 'however', 'him', 'anyhow', 'so', 'put', 'has', 'own', 'out', 'does', 'throughout', 'with', 'than', 'nor', 'third', 'elsewhere', 'do', 'some', "'ve", 'above', 'during', 'an', 'would', 'even', 'nowhere', 'take', 'before', 'he', 'them', 'whole', 'below', 'over', '‘re', 'our', 'yourselves', 'who', 'whenever', 'made', 'nothing', 'someone', 'whom', 'of', 'keep', 'hereafter', '’ll', 'namely', 'that', 'just', 'any', 'meanwhile', 'because', 'yet', 'can', 'everything', 'four', 'fifty', 'along', 'hereby', 'eleven', 'another', 'quite', 'nine', 'among', 'noone', 'although', 'seemed', 'though', 'together', 'somewhere', 'a', 'others', 'thus', '’m', 'toward', 'sometime', 'part', 'few', 'either', '‘m', 'amount', 'always', 'did', 'give', 'ten', 'myself', 'again', 'the', 'through', 'seem', 'n’t', 'get', 'beforehand', 'they', 'back', 'since', 'hereupon', 'beyond', 'various', 'herein', 'also', 'had', 'down', 'less', 'front', '‘ve', 'why', 'thereafter', 'bottom', 'used', 'have', 'perhaps', 'while', 'mostly', 'will', 'up', 'other', 'these', "'ll", 'every', '’ve', 'one', 'say', 'neither', 'latter', 'me', 'next', 'seems', 'us', 'not', 'whereby', 'whose', 'none', 'is', 'thereupon', '‘s', 'anyway', 'for', 'your', 'yourself', 'from', 'mine', 'five', 'go', 'formerly', 'ever', 'make', 'done', 'hers', "n't", 'six', 'we', 'off', 'here', 'wherever', 'hundred', 'very', 'three', 'thereby', 'call', 'until', 'eight', 'if', 'many', 'itself', 'top', 'please', 'in', 'but', 'whence', 'cannot', 'enough', 'all', 'hence', 'how', 'per', 'when', 'something', 'become', 'moreover', 'became', 'last', 'there', 'whereafter', 'thence', 'her', 'his', 'whereas', 'it', 'already', 'becoming', 'least', 'sometimes', 'as', 'otherwise', 'everywhere', 'might', 'was', 'full', 'unless', 'are', 'could', 'move', 'therein', 'around', 'regarding', 'against', 'name', 'further', 'himself', 'ca', 'see', 'themselves', 'serious', 'more', 'everyone', 'still', 'nobody', 'empty', 'rather', 'between', 'behind', 're', 'seeming', 'wherein', 'to', 'both', 'show', 'and', 'too', 'each', 'she', 'towards', '‘ll', 'thru', 'twenty', 'whereupon', 'after', 'ourselves', 'under', 'most', 'side', 'latterly', 'once', 'besides', 'therefore', 'at', 'without', 'its', 'else', 'much', 'about', '’s', 'two', 'herself', 'amongst', 'what', 'ours', '’d', 'must', 'using', 'anyone', 'never', 'whoever', 'now', "'m", 'may', 'often', 'upon', 'being', 'or', 'across'}

# %%
#Load the data set
data_raw = pd.read_csv("Data/tripadvisor_hotel_reviews.csv")
data_raw = data_raw[:][0:30]

# %%
def text_preprocessing1(text, strip_html=True, extra_whitespace=True, accented_chars=True, contraction=True, lowercase=True,
                       space_correction =True,
                       stop_words=True, punctuations=True, special_chars=True, remove_num=True, convert_num=True, lemmatization=True         
                       ):
    """preprocess text with default option set to true for all steps"""
    
    if strip_html == True: #convert all characters to lowercase
        soup = BeautifulSoup(text, "html.parser")
        text = soup.get_text(separator=" ")
    if extra_whitespace == True: #remove extra whitespaces
        text = text.strip()
        text = " ".join(text.split())
    if accented_chars == True: #remove accented characters
        text = unidecode.unidecode(text)
    if contraction == True: #expand contractions
        text = contractions.fix(text)
    if lowercase == True: #convert all characters to lowercase
        text = text.lower()
    if space_correction == True: #The regular expression loocs for cases where there is no whitespace after the end of a sentace
        text = re.sub(r'(?<=[.,])(?=[^\s])', r' ', text)
    return text

# %%
#Apply basic preprocessing
data_raw['Review'] = data_raw['Review'].apply(lambda x: text_preprocessing1(x, lowercase=False))

#Lemmatize all words
for t in range(len(data_raw['Review'])):
    doc = nlp(data_raw['Review'][t])
    data_raw['Review'][t]= str(" ".join([token.lemma_ for token in doc]))
# Out:
# C:\Users\unters1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#Calculate IDF_values
IDF_values = IDF(data_raw['Review'])

# %%
#Doing processing over the whole data, here 30
de = [ word2features(nlp(x), IDF_values,len(data_raw['Review'])) for x in data_raw['Review'] ]

# %%
de[1]
# Out:
# [[{'bias': 1.0,
#    'word': 'ok',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'UH',
#    'pos': 91,
#    'Len': 0.16666666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 5.788086,
#    'BOS': True,
#    '+1:word': 'nothing',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 95,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.10074515102711323,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.004161},
#   {'bias': 1.0,
#    'word': 'nothing',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 95,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.10074515102711323,
#    'DEP': 1,
#    'vect_norm': 5.004161,
#    '-1:word': 'ok',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'UH',
#    '-1:pos': 91,
#    '-1:Len': 0.16666666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.788086,
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word': 'special',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 5.4631042,
#    'BOS': True,
#    '+1:word': 'charge',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.5,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.10074515102711323,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.0295205},
#   {'bias': 1.0,
#    'word': 'charge',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.5,
#    'PoS': 1,
#    'TF*IDF': 0.10074515102711323,
#    'DEP': 1,
#    'vect_norm': 6.0295205,
#    '-1:word': 'special',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.4631042,
#    '+1:word': 'diamond',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.2934623},
#   {'bias': 1.0,
#    'word': 'diamond',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 7.2934623,
#    '-1:word': 'charge',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.5,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.10074515102711323,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.0295205,
#    '+1:word': 'member',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.5,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.6626935},
#   {'bias': 1.0,
#    'word': 'member',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.5,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 6.6626935,
#    '-1:word': 'diamond',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.2934623,
#    '+1:word': 'hilton',
#    '+1:isTitle': False,
#    '+1:entity': 'ORG',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.5,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.946893},
#   {'bias': 1.0,
#    'word': 'hilton',
#    'isTitle': False,
#    'entity': 'ORG',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.5,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 6.946893,
#    '-1:word': 'member',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.5,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.6626935,
#    '+1:word': 'decide',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VB',
#    '+1:pos': 100,
#    '+1:Len': 0.5,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.4257936},
#   {'bias': 1.0,
#    'word': 'decide',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VB',
#    'pos': 100,
#    'Len': 0.5,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 5.4257936,
#    '-1:word': 'hilton',
#    '-1:isTitle': False,
#    '-1:entity': 'ORG',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.5,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.946893,
#    '+1:word': 'chain',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.2302585092994046,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.839278},
#   {'bias': 1.0,
#    'word': 'chain',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.2302585092994046,
#    'DEP': 1,
#    'vect_norm': 6.839278,
#    '-1:word': 'decide',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VB',
#    '-1:pos': 100,
#    '-1:Len': 0.5,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.4257936,
#    '+1:word': 'shoot',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VB',
#    '+1:pos': 100,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1151292546497023,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.473554},
#   {'bias': 1.0,
#    'word': 'shoot',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VB',
#    'pos': 100,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.1151292546497023,
#    'DEP': 1,
#    'vect_norm': 6.473554,
#    '-1:word': 'chain',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.2302585092994046,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.839278,
#    '+1:word': '20th',
#    '+1:isTitle': False,
#    '+1:entity': 'ORDINAL',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.270805020110221,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.0060654},
#   {'bias': 1.0,
#    'word': '20th',
#    'isTitle': False,
#    'entity': 'ORDINAL',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.270805020110221,
#    'DEP': 1,
#    'vect_norm': 6.0060654,
#    '-1:word': 'shoot',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VB',
#    '-1:pos': 100,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1151292546497023,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.473554,
#    '+1:word': 'anniversary',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.9166666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.20149030205422647,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.5445976},
#   {'bias': 1.0,
#    'word': 'anniversary',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.9166666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.20149030205422647,
#    'DEP': 1,
#    'vect_norm': 6.5445976,
#    '-1:word': '20th',
#    '-1:isTitle': False,
#    '-1:entity': 'ORDINAL',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.270805020110221,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.0060654,
#    '+1:word': 'seattle',
#    '+1:isTitle': False,
#    '+1:entity': 'GPE',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.07662384356489861,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.4831614},
#   {'bias': 1.0,
#    'word': 'seattle',
#    'isTitle': False,
#    'entity': 'GPE',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.07662384356489861,
#    'DEP': 1,
#    'vect_norm': 6.4831614,
#    '-1:word': 'anniversary',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.9166666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.20149030205422647,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.5445976,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'seattle',
#    '-1:isTitle': False,
#    '-1:entity': 'GPE',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.07662384356489861,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.4831614,
#    '+1:word': 'start',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VB',
#    '+1:pos': 100,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.20149030205422647,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.4621725},
#   {'bias': 1.0,
#    'word': 'start',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VB',
#    'pos': 100,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.20149030205422647,
#    'DEP': 1,
#    'vect_norm': 5.4621725,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    '+1:word': 'book',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.04581453659370776,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.4986963},
#   {'bias': 1.0,
#    'word': 'book',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.04581453659370776,
#    'DEP': 1,
#    'vect_norm': 6.4986963,
#    '-1:word': 'start',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VB',
#    '-1:pos': 100,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.20149030205422647,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.4621725,
#    '+1:word': 'suite',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.15242801040937937,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.9257517},
#   {'bias': 1.0,
#    'word': 'suite',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.15242801040937937,
#    'DEP': 1,
#    'vect_norm': 6.9257517,
#    '-1:word': 'book',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.04581453659370776,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.4986963,
#    '+1:word': 'pay',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VBP',
#    '+1:pos': 100,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.08958797346140275,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.239512},
#   {'bias': 1.0,
#    'word': 'pay',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VBP',
#    'pos': 100,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': 0.08958797346140275,
#    'DEP': 1,
#    'vect_norm': 6.239512,
#    '-1:word': 'suite',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.15242801040937937,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.9257517,
#    '+1:word': 'extra',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.868335},
#   {'bias': 1.0,
#    'word': 'extra',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 5.868335,
#    '-1:word': 'pay',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VBP',
#    '-1:pos': 100,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.08958797346140275,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.239512,
#    '+1:word': 'website',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.30099320108148403,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.030768},
#   {'bias': 1.0,
#    'word': 'website',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.30099320108148403,
#    'DEP': 1,
#    'vect_norm': 6.030768,
#    '-1:word': 'extra',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.868335,
#    '+1:word': 'description',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.9166666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.34538776394910686,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.1372466},
#   {'bias': 1.0,
#    'word': 'description',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.9166666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.34538776394910686,
#    'DEP': 1,
#    'vect_norm': 5.1372466,
#    '-1:word': 'website',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.30099320108148403,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.030768,
#    '+1:word': 'not',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'RB',
#    '+1:pos': 94,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.05006525718160242,
#    '+1:DEP': 1,
#    '+1:vect_norm': 4.9436083},
#   {'bias': 1.0,
#    'word': 'not',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'RB',
#    'pos': 94,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': -0.05006525718160242,
#    'DEP': 1,
#    'vect_norm': 4.9436083,
#    '-1:word': 'description',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.9166666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.34538776394910686,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.1372466,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'not',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'RB',
#    '-1:pos': 94,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.05006525718160242,
#    '-1:DEP': 1,
#    '-1:vect_norm': 4.9436083,
#    '+1:word': 'suite',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.15242801040937937,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.9257517},
#   {'bias': 1.0,
#    'word': 'suite',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.15242801040937937,
#    'DEP': 1,
#    'vect_norm': 6.9257517,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    '+1:word': 'bedroom',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.270805020110221,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.6669154},
#   {'bias': 1.0,
#    'word': 'bedroom',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.270805020110221,
#    'DEP': 1,
#    'vect_norm': 7.6669154,
#    '-1:word': 'suite',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.15242801040937937,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.9257517,
#    '+1:word': 'bathroom',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.6666666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.10033021088637849,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.59594},
#   {'bias': 1.0,
#    'word': 'bathroom',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.6666666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.10033021088637849,
#    'DEP': 1,
#    'vect_norm': 7.59594,
#    '-1:word': 'bedroom',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.270805020110221,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.6669154,
#    '+1:word': 'standard',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.6666666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.08047189562170502,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.0297666},
#   {'bias': 1.0,
#    'word': 'standard',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.6666666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.08047189562170502,
#    'DEP': 1,
#    'vect_norm': 6.0297666,
#    '-1:word': 'bathroom',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.6666666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.10033021088637849,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.59594,
#    '+1:word': 'hotel',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.3766488014856179,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.93165},
#   {'bias': 1.0,
#    'word': 'hotel',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': -0.3766488014856179,
#    'DEP': 1,
#    'vect_norm': 7.93165,
#    '-1:word': 'standard',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.6666666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.08047189562170502,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.0297666,
#    '+1:word': 'room',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.2827824120574585,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.615803},
#   {'bias': 1.0,
#    'word': 'room',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': -0.2827824120574585,
#    'DEP': 1,
#    'vect_norm': 6.615803,
#    '-1:word': 'hotel',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.3766488014856179,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.93165,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'room',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.2827824120574585,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.615803,
#    '+1:word': 'take',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VB',
#    '+1:pos': 100,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.03810700260234484,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.164581},
#   {'bias': 1.0,
#    'word': 'take',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VB',
#    'pos': 100,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.03810700260234484,
#    'DEP': 1,
#    'vect_norm': 5.164581,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word': 'print',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.10074515102711323,
#    'DEP': 1,
#    'vect_norm': 6.579434,
#    'BOS': True,
#    '+1:word': 'reservation',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.9166666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.3022354530813397,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.738819},
#   {'bias': 1.0,
#    'word': 'reservation',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.9166666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.3022354530813397,
#    'DEP': 1,
#    'vect_norm': 6.738819,
#    '-1:word': 'print',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.10074515102711323,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.579434,
#    '+1:word': 'desk',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.04462871026284196,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.6813564},
#   {'bias': 1.0,
#    'word': 'desk',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.04462871026284196,
#    'DEP': 1,
#    'vect_norm': 6.6813564,
#    '-1:word': 'reservation',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.9166666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.3022354530813397,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.738819,
#    '+1:word': 'show',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1151292546497023,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.7058887},
#   {'bias': 1.0,
#    'word': 'show',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.1151292546497023,
#    'DEP': 1,
#    'vect_norm': 5.7058887,
#    '-1:word': 'desk',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.04462871026284196,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.6813564,
#    '+1:word': 'say',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VBP',
#    '+1:pos': 100,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.0456758402495715,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.2076726},
#   {'bias': 1.0,
#    'word': 'say',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VBP',
#    'pos': 100,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': 0.0456758402495715,
#    'DEP': 1,
#    'vect_norm': 5.2076726,
#    '-1:word': 'show',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1151292546497023,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.7058887,
#    '+1:word': 'thing',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.06019864021629681,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.1390543},
#   {'bias': 1.0,
#    'word': 'thing',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.06019864021629681,
#    'DEP': 1,
#    'vect_norm': 5.1390543,
#    '-1:word': 'say',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VBP',
#    '-1:pos': 100,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.0456758402495715,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.2076726,
#    '+1:word': 'like',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'IN',
#    '+1:pos': 98,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.031015492830383948,
#    '+1:DEP': 1,
#    '+1:vect_norm': 4.78322},
#   {'bias': 1.0,
#    'word': 'like',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'IN',
#    'pos': 98,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.031015492830383948,
#    'DEP': 1,
#    'vect_norm': 4.78322,
#    '-1:word': 'thing',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.06019864021629681,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.1390543,
#    '+1:word': 'tv',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.16666666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.08958797346140275,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.157099},
#   {'bias': 1.0,
#    'word': 'tv',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.16666666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.08958797346140275,
#    'DEP': 1,
#    'vect_norm': 7.157099,
#    '-1:word': 'like',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'IN',
#    '-1:pos': 98,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.031015492830383948,
#    '-1:DEP': 1,
#    '-1:vect_norm': 4.78322,
#    '+1:word': 'couch',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1151292546497023,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.5084586},
#   {'bias': 1.0,
#    'word': 'couch',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.1151292546497023,
#    'DEP': 1,
#    'vect_norm': 6.5084586,
#    '-1:word': 'tv',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.16666666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.08958797346140275,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.157099,
#    '+1:word': 'ect',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 4.941732},
#   {'bias': 1.0,
#    'word': 'ect',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 4.941732,
#    '-1:word': 'couch',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1151292546497023,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.5084586,
#    '+1:word': 'desk',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.04462871026284196,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.6813564},
#   {'bias': 1.0,
#    'word': 'desk',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.04462871026284196,
#    'DEP': 1,
#    'vect_norm': 6.6813564,
#    '-1:word': 'ect',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 4.941732,
#    '+1:word': 'clerk',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1151292546497023,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.7495513},
#   {'bias': 1.0,
#    'word': 'clerk',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.1151292546497023,
#    'DEP': 1,
#    'vect_norm': 6.7495513,
#    '-1:word': 'desk',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.04462871026284196,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.6813564,
#    '+1:word': 'tell',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VB',
#    '+1:pos': 100,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.20066042177275698,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.319511},
#   {'bias': 1.0,
#    'word': 'tell',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VB',
#    'pos': 100,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.20066042177275698,
#    'DEP': 1,
#    'vect_norm': 5.319511,
#    '-1:word': 'clerk',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1151292546497023,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.7495513,
#    '+1:word': 'oh',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'UH',
#    '+1:pos': 91,
#    '+1:Len': 0.16666666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.044095},
#   {'bias': 1.0,
#    'word': 'oh',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'UH',
#    'pos': 91,
#    'Len': 0.16666666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 6.044095,
#    '-1:word': 'tell',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VB',
#    '-1:pos': 100,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.20066042177275698,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.319511,
#    '+1:word': 'mixed',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.8474455},
#   {'bias': 1.0,
#    'word': 'mixed',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 5.8474455,
#    '-1:word': 'oh',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'UH',
#    '-1:pos': 91,
#    '-1:Len': 0.16666666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.044095,
#    '+1:word': 'suites',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNS',
#    '+1:pos': 92,
#    '+1:Len': 0.5,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.6105347},
#   {'bias': 1.0,
#    'word': 'suites',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNS',
#    'pos': 92,
#    'Len': 0.5,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 7.6105347,
#    '-1:word': 'mixed',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.8474455,
#    '+1:word': 'description',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.9166666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.34538776394910686,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.1372466},
#   {'bias': 1.0,
#    'word': 'description',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.9166666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.34538776394910686,
#    'DEP': 1,
#    'vect_norm': 5.1372466,
#    '-1:word': 'suites',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNS',
#    '-1:pos': 92,
#    '-1:Len': 0.5,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.6105347,
#    '+1:word': 'kimpton',
#    '+1:isTitle': False,
#    '+1:entity': 'ORG',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.15049531632956772,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.446196},
#   {'bias': 1.0,
#    'word': 'kimpton',
#    'isTitle': False,
#    'entity': 'ORG',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.15049531632956772,
#    'DEP': 1,
#    'vect_norm': 7.446196,
#    '-1:word': 'description',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.9166666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.34538776394910686,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.1372466,
#    '+1:word': 'website',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.30099320108148403,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.030768},
#   {'bias': 1.0,
#    'word': 'website',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.30099320108148403,
#    'DEP': 1,
#    'vect_norm': 6.030768,
#    '-1:word': 'kimpton',
#    '-1:isTitle': False,
#    '-1:entity': 'ORG',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.15049531632956772,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.446196,
#    '+1:word': 'sorry',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'UH',
#    '+1:pos': 91,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.7327576},
#   {'bias': 1.0,
#    'word': 'sorry',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'UH',
#    'pos': 91,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 5.7327576,
#    '-1:word': 'website',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.30099320108148403,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.030768,
#    '+1:word': 'free',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.0727643616303421,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.4880733},
#   {'bias': 1.0,
#    'word': 'free',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.0727643616303421,
#    'DEP': 1,
#    'vect_norm': 6.4880733,
#    '-1:word': 'sorry',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'UH',
#    '-1:pos': 91,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.7327576,
#    '+1:word': 'breakfast',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.75,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.2687639203842082,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.331563},
#   {'bias': 1.0,
#    'word': 'breakfast',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.75,
#    'PoS': 1,
#    'TF*IDF': 0.2687639203842082,
#    'DEP': 1,
#    'vect_norm': 7.331563,
#    '-1:word': 'free',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.0727643616303421,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.4880733,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'breakfast',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.75,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.2687639203842082,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.331563,
#    '+1:word': 'get',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VB',
#    '+1:pos': 87,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.08519760564089089,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.107025},
#   {'bias': 1.0,
#    'word': 'get',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VB',
#    'pos': 87,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': 0.08519760564089089,
#    'DEP': 1,
#    'vect_norm': 5.107025,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    '+1:word': 'kid',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.117723},
#   {'bias': 1.0,
#    'word': 'kid',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 6.117723,
#    '-1:word': 'get',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VB',
#    '-1:pos': 87,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.08519760564089089,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.107025,
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    'BOS': True,
#    '+1:word': 'embassy',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.9944105},
#   {'bias': 1.0,
#    'word': 'embassy',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 6.9944105,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    '+1:word': 'suit',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.887129},
#   {'bias': 1.0,
#    'word': 'suit',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 5.887129,
#    '-1:word': 'embassy',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.9944105,
#    '+1:word': 'sit',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VBP',
#    '+1:pos': 100,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.10074515102711323,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.782645},
#   {'bias': 1.0,
#    'word': 'sit',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VBP',
#    'pos': 100,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': 0.10074515102711323,
#    'DEP': 1,
#    'vect_norm': 5.782645,
#    '-1:word': 'suit',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.887129,
#    '+1:word': 'room',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.2827824120574585,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.615803},
#   {'bias': 1.0,
#    'word': 'room',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': -0.2827824120574585,
#    'DEP': 1,
#    'vect_norm': 6.615803,
#    '-1:word': 'sit',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VBP',
#    '-1:pos': 100,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.10074515102711323,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.782645,
#    '+1:word': 'bathroom',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.6666666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.10033021088637849,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.59594},
#   {'bias': 1.0,
#    'word': 'bathroom',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.6666666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.10033021088637849,
#    'DEP': 1,
#    'vect_norm': 7.59594,
#    '-1:word': 'room',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.2827824120574585,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.615803,
#    '+1:word': 'bedroom',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.270805020110221,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.6669154},
#   {'bias': 1.0,
#    'word': 'bedroom',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.270805020110221,
#    'DEP': 1,
#    'vect_norm': 7.6669154,
#    '-1:word': 'bathroom',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.6666666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.10033021088637849,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.59594,
#    '+1:word': 'unlike',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'IN',
#    '+1:pos': 85,
#    '+1:Len': 0.5,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 4.449875},
#   {'bias': 1.0,
#    'word': 'unlike',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'IN',
#    'pos': 85,
#    'Len': 0.5,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 4.449875,
#    '-1:word': 'bedroom',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.270805020110221,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.6669154,
#    '+1:word': 'kimpton',
#    '+1:isTitle': False,
#    '+1:entity': 'ORG',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.15049531632956772,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.446196},
#   {'bias': 1.0,
#    'word': 'kimpton',
#    'isTitle': False,
#    'entity': 'ORG',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.15049531632956772,
#    'DEP': 1,
#    'vect_norm': 7.446196,
#    '-1:word': 'unlike',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'IN',
#    '-1:pos': 85,
#    '-1:Len': 0.5,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 4.449875,
#    '+1:word': 'call',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.04181240121003093,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.786145},
#   {'bias': 1.0,
#    'word': 'call',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.04181240121003093,
#    'DEP': 1,
#    'vect_norm': 5.786145,
#    '-1:word': 'kimpton',
#    '-1:isTitle': False,
#    '-1:entity': 'ORG',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.15049531632956772,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.446196,
#    '+1:word': 'suite',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.15242801040937937,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.9257517},
#   {'bias': 1.0,
#    'word': 'suite',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.15242801040937937,
#    'DEP': 1,
#    'vect_norm': 6.9257517,
#    '-1:word': 'call',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.04181240121003093,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.786145,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'suite',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.15242801040937937,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.9257517,
#    '+1:word': '5',
#    '+1:isTitle': False,
#    '+1:entity': 'DATE',
#    '+1:tag': 'CD',
#    '+1:pos': 93,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.08047189562170502,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.069743},
#   {'bias': 1.0,
#    'word': '5',
#    'isTitle': False,
#    'entity': 'DATE',
#    'tag': 'CD',
#    'pos': 93,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.08047189562170502,
#    'DEP': 1,
#    'vect_norm': 5.069743,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    '+1:word': 'day',
#    '+1:isTitle': False,
#    '+1:entity': 'DATE',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.054930614433405495,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.5376587},
#   {'bias': 1.0,
#    'word': 'day',
#    'isTitle': False,
#    'entity': 'DATE',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': 0.054930614433405495,
#    'DEP': 1,
#    'vect_norm': 5.5376587,
#    '-1:word': '5',
#    '-1:isTitle': False,
#    '-1:entity': 'DATE',
#    '-1:tag': 'CD',
#    '-1:pos': 93,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.08047189562170502,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.069743,
#    '+1:word': 'stay',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.022447511002395157,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.940785},
#   {'bias': 1.0,
#    'word': 'stay',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': -0.022447511002395157,
#    'DEP': 1,
#    'vect_norm': 5.940785,
#    '-1:word': 'day',
#    '-1:isTitle': False,
#    '-1:entity': 'DATE',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.054930614433405495,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.5376587,
#    '+1:word': 'offer',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.10074515102711323,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.8833394},
#   {'bias': 1.0,
#    'word': 'offer',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.10074515102711323,
#    'DEP': 1,
#    'vect_norm': 5.8833394,
#    '-1:word': 'stay',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.022447511002395157,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.940785,
#    '+1:word': 'correct',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.607515},
#   {'bias': 1.0,
#    'word': 'correct',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 5.607515,
#    '-1:word': 'offer',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
# ...
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.03566749439387324,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.100895},
#   {'bias': 1.0,
#    'word': 'night',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.03566749439387324,
#    'DEP': 1,
#    'vect_norm': 6.100895,
#    '-1:word': 'eye',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.0221086,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'night',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.03566749439387324,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.100895,
#    '+1:word': 'light',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.08958797346140275,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.3932247},
#   {'bias': 1.0,
#    'word': 'light',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.08958797346140275,
#    'DEP': 1,
#    'vect_norm': 6.3932247,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    '+1:word': 'sensitive',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.75,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.3224835},
#   {'bias': 1.0,
#    'word': 'sensitive',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.75,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 6.3224835,
#    '-1:word': 'light',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.08958797346140275,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.3932247,
#    '+1:word': 'tape',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.17005986908310777,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.9668036},
#   {'bias': 1.0,
#    'word': 'tape',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.17005986908310777,
#    'DEP': 1,
#    'vect_norm': 6.9668036,
#    '-1:word': 'sensitive',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.75,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.3224835,
#    '+1:word': 'control',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.270805020110221,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.4051557},
#   {'bias': 1.0,
#    'word': 'control',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.270805020110221,
#    'DEP': 1,
#    'vect_norm': 6.4051557,
#    '-1:word': 'tape',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.17005986908310777,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.9668036,
#    '+1:word': '.',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': '.',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.10216512475319815,
#    '+1:DEP': 1,
#    '+1:vect_norm': 4.9316354},
#   {'bias': 1.0,
#    'word': '.',
#    'isTitle': False,
#    'entity': '',
#    'tag': '.',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -0.10216512475319815,
#    'DEP': 1,
#    'vect_norm': 4.9316354,
#    '-1:word': 'control',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.270805020110221,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.4051557,
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word': 'this',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'DT',
#    'pos': 90,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 5.0461264,
#    'BOS': True,
#    '+1:word': 'not',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'RB',
#    '+1:pos': 94,
#    '+1:Len': 0.25,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.05006525718160242,
#    '+1:DEP': 1,
#    '+1:vect_norm': 4.9436083},
#   {'bias': 1.0,
#    'word': 'not',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'RB',
#    'pos': 94,
#    'Len': 0.25,
#    'PoS': 1,
#    'TF*IDF': -0.05006525718160242,
#    'DEP': 1,
#    'vect_norm': 4.9436083,
#    '-1:word': 'this',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'DT',
#    '-1:pos': 90,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.0461264,
#    '+1:word': '4',
#    '+1:isTitle': False,
#    '+1:entity': 'CARDINAL',
#    '+1:tag': 'CD',
#    '+1:pos': 93,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.16479184330021646,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.05721},
#   {'bias': 1.0,
#    'word': '4',
#    'isTitle': False,
#    'entity': 'CARDINAL',
#    'tag': 'CD',
#    'pos': 93,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.16479184330021646,
#    'DEP': 1,
#    'vect_norm': 5.05721,
#    '-1:word': 'not',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'RB',
#    '-1:pos': 94,
#    '-1:Len': 0.25,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.05006525718160242,
#    '-1:DEP': 1,
#    '-1:vect_norm': 4.9436083,
#    '+1:word': 'start',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'VBP',
#    '+1:pos': 100,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.20149030205422647,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.4621725},
#   {'bias': 1.0,
#    'word': 'start',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'VBP',
#    'pos': 100,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.20149030205422647,
#    'DEP': 1,
#    'vect_norm': 5.4621725,
#    '-1:word': '4',
#    '-1:isTitle': False,
#    '-1:entity': 'CARDINAL',
#    '-1:tag': 'CD',
#    '-1:pos': 93,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.16479184330021646,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.05721,
#    '+1:word': 'hotel',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.3766488014856179,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.93165},
#   {'bias': 1.0,
#    'word': 'hotel',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': -0.3766488014856179,
#    'DEP': 1,
#    'vect_norm': 7.93165,
#    '-1:word': 'start',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'VBP',
#    '-1:pos': 100,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.20149030205422647,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.4621725,
#    '+1:word': 'clean',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.10033021088637849,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.4559617},
#   {'bias': 1.0,
#    'word': 'clean',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.10033021088637849,
#    'DEP': 1,
#    'vect_norm': 6.4559617,
#    '-1:word': 'hotel',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.3766488014856179,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.93165,
#    '+1:word': 'business',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.6666666666666666,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.0727643616303421,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.409597},
#   {'bias': 1.0,
#    'word': 'business',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.6666666666666666,
#    'PoS': 1,
#    'TF*IDF': 0.0727643616303421,
#    'DEP': 1,
#    'vect_norm': 6.409597,
#    '-1:word': 'clean',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.10033021088637849,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.4559617,
#    '+1:word': 'hotel',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.3766488014856179,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.93165},
#   {'bias': 1.0,
#    'word': 'hotel',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': -0.3766488014856179,
#    'DEP': 1,
#    'vect_norm': 7.93165,
#    '-1:word': 'business',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.6666666666666666,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.0727643616303421,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.409597,
#    '+1:word': 'super',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.1354025100551105,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.222262},
#   {'bias': 1.0,
#    'word': 'super',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.1354025100551105,
#    'DEP': 1,
#    'vect_norm': 6.222262,
#    '-1:word': 'hotel',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.3766488014856179,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.93165,
#    '+1:word': 'high',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'JJ',
#    '+1:pos': 84,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.13217558399823195,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.846882},
#   {'bias': 1.0,
#    'word': 'high',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'JJ',
#    'pos': 84,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.13217558399823195,
#    'DEP': 1,
#    'vect_norm': 5.846882,
#    '-1:word': 'super',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.1354025100551105,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.222262,
#    '+1:word': 'rate',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.08958797346140275,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.8548427},
#   {'bias': 1.0,
#    'word': 'rate',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.08958797346140275,
#    'DEP': 1,
#    'vect_norm': 6.8548427,
#    '-1:word': 'high',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'JJ',
#    '-1:pos': 84,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.13217558399823195,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.846882,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'rate',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.08958797346140275,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.8548427,
#    '+1:word': 'well',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'RB',
#    '+1:pos': 86,
#    '+1:Len': 0.3333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.12039728043259362,
#    '+1:DEP': 1,
#    '+1:vect_norm': 4.615075},
#   {'bias': 1.0,
#    'word': 'well',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'RB',
#    'pos': 86,
#    'Len': 0.3333333333333333,
#    'PoS': 1,
#    'TF*IDF': 0.12039728043259362,
#    'DEP': 1,
#    'vect_norm': 4.615075,
#    '-1:word': ',',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': ',',
#    '-1:pos': 97,
#    '-1:Len': 0.08333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -2.4652706752711415,
#    '-1:DEP': 1,
#    '-1:vect_norm': 5.094723,
#    '+1:word': 'chain',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NN',
#    '+1:pos': 92,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.2302585092994046,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.839278},
#   {'bias': 1.0,
#    'word': 'chain',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NN',
#    'pos': 92,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': 0.2302585092994046,
#    'DEP': 1,
#    'vect_norm': 6.839278,
#    '-1:word': 'well',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'RB',
#    '-1:pos': 86,
#    '-1:Len': 0.3333333333333333,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.12039728043259362,
#    '-1:DEP': 1,
#    '-1:vect_norm': 4.615075,
#    '+1:word': 'hotel',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.4166666666666667,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -0.3766488014856179,
#    '+1:DEP': 1,
#    '+1:vect_norm': 7.93165},
#   {'bias': 1.0,
#    'word': 'hotel',
#    'isTitle': False,
#    'entity': '',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.4166666666666667,
#    'PoS': 1,
#    'TF*IDF': -0.3766488014856179,
#    'DEP': 1,
#    'vect_norm': 7.93165,
#    '-1:word': 'chain',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NN',
#    '-1:pos': 92,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.2302585092994046,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.839278,
#    '+1:word': 'seattle',
#    '+1:isTitle': False,
#    '+1:entity': 'GPE',
#    '+1:tag': 'NNP',
#    '+1:pos': 96,
#    '+1:Len': 0.5833333333333334,
#    '+1:PoS': 1,
#    '+1:TF*IDF': 0.07662384356489861,
#    '+1:DEP': 1,
#    '+1:vect_norm': 6.4831614},
#   {'bias': 1.0,
#    'word': 'seattle',
#    'isTitle': False,
#    'entity': 'GPE',
#    'tag': 'NNP',
#    'pos': 96,
#    'Len': 0.5833333333333334,
#    'PoS': 1,
#    'TF*IDF': 0.07662384356489861,
#    'DEP': 1,
#    'vect_norm': 6.4831614,
#    '-1:word': 'hotel',
#    '-1:isTitle': False,
#    '-1:entity': '',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.4166666666666667,
#    '-1:PoS': 1,
#    '-1:TF*IDF': -0.3766488014856179,
#    '-1:DEP': 1,
#    '-1:vect_norm': 7.93165,
#    '+1:word': ',',
#    '+1:isTitle': False,
#    '+1:entity': '',
#    '+1:tag': ',',
#    '+1:pos': 97,
#    '+1:Len': 0.08333333333333333,
#    '+1:PoS': 1,
#    '+1:TF*IDF': -2.4652706752711415,
#    '+1:DEP': 1,
#    '+1:vect_norm': 5.094723},
#   {'bias': 1.0,
#    'word': ',',
#    'isTitle': False,
#    'entity': '',
#    'tag': ',',
#    'pos': 97,
#    'Len': 0.08333333333333333,
#    'PoS': 1,
#    'TF*IDF': -2.4652706752711415,
#    'DEP': 1,
#    'vect_norm': 5.094723,
#    '-1:word': 'seattle',
#    '-1:isTitle': False,
#    '-1:entity': 'GPE',
#    '-1:tag': 'NNP',
#    '-1:pos': 96,
#    '-1:Len': 0.5833333333333334,
#    '-1:PoS': 1,
#    '-1:TF*IDF': 0.07662384356489861,
#    '-1:DEP': 1,
#    '-1:vect_norm': 6.4831614,
#    'EOS': True}]]

# %%
data_raw['Review'][1]
# Out:
# 'ok nothing special charge diamond member hilton decide chain shoot 20th anniversary seattle , start book suite pay extra website description not , suite bedroom bathroom standard hotel room , take print reservation desk show say thing like tv couch ect desk clerk tell oh mixed suites description kimpton website sorry free breakfast , get kid , embassy suit sit room bathroom bedroom unlike kimpton call suite , 5 day stay offer correct false advertising , send kimpton preferred guest website email ask failure provide suite advertise website reservation description furnish hard copy reservation printout website desk manager duty do not reply solution , send email trip guest survey do not follow email mail , guess tell concerned guest . the staff range indifferent not helpful , ask desk good breakfast spot neighborhood hood tell no hotel , gee good breakfast spot seattle 1/2 block away convenient hotel do not know exist , arrive late night 11 pm inside run bellman busy chat cell phone help bag . prior arrival email hotel inform 20th anniversary half really picky want make sure good , get nice email say like deliver bottle champagne chocolate cover strawberry room arrival celebrate , tell need foam pillow , arrival no champagne strawberry no foam pillow great room view alley high rise build good not well housekeeping staff clean room property , impress left morning shopping room get short trip 2 hour , bed comfortable . not good ac - heat control 4 x 4 inch screen bring green shine directly eye night , light sensitive tape control . this not 4 start hotel clean business hotel super high rate , well chain hotel seattle ,'
