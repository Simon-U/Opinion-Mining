# %%
import pandas as pd
import numpy as np
from LDA_preprocessing import *
from sentiment_functions import *
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
from gensim.models import CoherenceModel
# %matplotlib inline
from progressbar import ProgressBar
pbar = ProgressBar()

# %%
#Load the data set
data_raw = pd.read_csv("Data/tripadvisor_hotel_reviews.csv")
data_in = data_raw['Review']

# %%
results = lda_processing(data_in, model = 'bi_gram')
# Out:
# Initial processing completed
# Sentence to word complete
# Bigram, Trigram model derived
# Bigram words derived
# Data lemmatized
# Processing completed

# %%
corpus = results['text_corpus']
id2word = results['id2word']
texts = results['data_output']

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=6,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           decay = 0.7,
                                           per_word_topics=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a431b03f7bd4> in <module>
#       8                                            alpha='auto',
#       9                                            decay = 0.7,
# ---> 10                                            per_word_topics=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\models\ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     517         if corpus is not None:
#     518             use_numpy = self.dispatcher is not None
# --> 519             self.update(corpus, chunks_as_numpy=use_numpy)
#     520
#     521     def init_dir_prior(self, prior, name):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\models\ldamodel.py in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     978                         pass_, chunk_no * chunksize + len(chunk), lencorpus
#     979                     )
# --> 980                     gammat = self.do_estep(chunk, other)
#     981
#     982                     if self.optimize_alpha:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\models\ldamodel.py in do_estep(self, chunk, state)
#     740         if state is None:
#     741             state = self.state
# --> 742         gamma, sstats = self.inference(chunk, collect_sstats=True)
#     743         state.sstats += sstats
#     744         state.numdocs += gamma.shape[0]  # avoids calling len(chunk) on a generator
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\models\ldamodel.py in inference(self, chunk, collect_sstats)
#     705                 # Contribution of document d to the expected sufficient
#     706                 # statistics for the M step.
# --> 707                 sstats[:, ids] += np.outer(expElogthetad.T, cts / phinorm)
#     708
#     709         if len(chunk) > 1:
#
# KeyboardInterrupt:

# %%
# Compute Coherence Score
cm = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
cm.get_coherence()
# Out:
# 0.388721884027752

# %%
coh_mat = pd.DataFrame(index=range(0,30),columns=['bi_gram','tri_gram'], dtype='float')
mod = ['bi_gram','tri_gram']
for i in mod:
    print(i)
    results = lda_processing(data_in, model = i)
    corpus = results['text_corpus']
    id2word = results['id2word']
    texts = results['data_output']
    k = 1
    
    #K funktioniert nicht richtig. Hier muss ich die Loop richtig anpassen
    
    
    for k in pbar(range(1,3)):
        lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics= k,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           decay = 0.7,
                                           per_word_topics=True)
        cm = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
        coh_mat[i][k] = cm.get_coherence()
# Out:
# bi_gram
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-eb1c66a6d12f> in <module>
#       8     texts = results['data_output']
#       9     k = 1
# ---> 10     for k in pbar(range(1,3)):
#      11         print(k)
#      12         lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\progressbar\progressbar.py in __next__(self)
#     152                 self.start()
#     153             else:
# --> 154                 self.update(self.currval + 1)
#     155             return value
#     156         except StopIteration:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\progressbar\progressbar.py in update(self, value)
#     248                 and not 0 <= value <= self.maxval):
#     249
# --> 250                 raise ValueError('Value out of range')
#     251
#     252             self.currval = value
#
# ValueError: Value out of range

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.164222 -0.092651       1        1  43.493659
# 0     -0.229253  0.000012       2        1  28.114225
# 2     -0.157257 -0.176989       3        1  15.662225
# 3     -0.056982  0.344076       4        1   8.667720
# 4      0.285958 -0.014396       5        1   2.170010
# 5      0.321756 -0.060053       6        1   1.892161, topic_info=          Term          Freq         Total Category  logprob  loglift
# 22       hotel  44674.000000  44674.000000  Default  30.0000  30.0000
# 46        room  46431.000000  46431.000000  Default  29.0000  29.0000
# 4012    resort   7074.000000   7074.000000  Default  28.0000  28.0000
# 373       food   9180.000000   9180.000000  Default  27.0000  27.0000
# 50        stay  25513.000000  25513.000000  Default  26.0000  26.0000
# ...        ...           ...           ...      ...      ...      ...
# 2911  american    164.108218    322.710248   Topic6  -5.2018   3.2912
# 1810     carry    149.832244    307.809301   Topic6  -5.2928   3.2475
# 1497      fast    163.398843    609.384407   Topic6  -5.2062   2.6512
# 936      slide    130.378630    198.159993   Topic6  -5.4319   3.5488
# 567        key    131.413111    908.632512   Topic6  -5.4240   2.0339
#
# [373 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 1126      1  0.016421  absolutely
# 1126      2  0.983276  absolutely
# 350       1  0.999322      access
# 286       4  0.998831    activity
# 972       2  0.999595     amazing
# ...     ...       ...         ...
# 1286      2  0.997799       world
# 2119      2  0.998313       worry
# 664       1  0.007210        year
# 664       2  0.983222        year
# 664       3  0.009107        year
#
# [575 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 3, 4, 5, 6])

# %%
#Show one topic
lda_model.show_topic(0)
# Out:
# [('time', 0.021955444),
#  ('great', 0.019978188),
#  ('day', 0.016722651),
#  ('really', 0.015067111),
#  ('go', 0.013831164),
#  ('place', 0.012870711),
#  ('good', 0.012534356),
#  ('want', 0.012367976),
#  ('get', 0.010793216),
#  ('people', 0.010266776)]

# %%
#Function to print all the topics
for topic_id in range(lda_model.num_topics):
    topk = lda_model.show_topic(topic_id, 10)
    topk_words = [ w for w, _ in topk ]
    
    print('{}: {}'.format(topic_id, ' '.join(topk_words)))
# Out:
# 0: time great day really go place good want get people
# 1: hotel room stay good great staff location night breakfast clean
# 2: room check ask tell say get leave bad day arrive
# 3: resort pool beach food water good drink buffet vacation restaurant
# 4: shower smell toilet light wall sheet class sink bathroom tile
# 5: phone boat chinese plane careful privacy lock cash tend general

# %%
#Get the Topic for a new document
doc = data_raw['Review'][1].split()

doc_vector = lda_model.id2word.doc2bow(doc)
doc_topics = lda_model[doc_vector]

# %%
#Sorted Topic for the document. Only the top 2 or 3 topics will be added
df =pd.DataFrame(doc_topics[0])
df.sort_values(1, ascending=False)
# Out:
#    0         1
# 1  1  0.439658
# 2  2  0.275970
# 0  0  0.168709
# 5  5  0.065461
# 4  4  0.040105
# 3  3  0.010097

# %%
coh_mat
# Out:
#     bi_gram  tri_gram
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
# 5       NaN       NaN
# 6       NaN       NaN
# 7       NaN       NaN
# 8       NaN       NaN
# 9       NaN       NaN
# 10      NaN       NaN
# 11      NaN       NaN
# 12      NaN       NaN
# 13      NaN       NaN
# 14      NaN       NaN
# 15      NaN       NaN
# 16      NaN       NaN
# 17      NaN       NaN
# 18      NaN       NaN
# 19      NaN       NaN
# 20      NaN       NaN
# 21      NaN       NaN
# 22      NaN       NaN
# 23      NaN       NaN
# 24      NaN       NaN
# 25      NaN       NaN
# 26      NaN       NaN
# 27      NaN       NaN
# 28      NaN       NaN
# 29      NaN       NaN

# %%
k
# Out:
# 0
